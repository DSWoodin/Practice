# %% [markdown]
# <a href="https://colab.research.google.com/github/DSWoodin/Pythonworkspace/blob/main/ProDS/%EB%AA%A8%ED%8F%89%EA%B7%A0%EB%B9%84%EA%B5%90%EC%97%90%EA%B4%80%ED%95%9C%EA%B0%80%EC%84%A4%EA%B2%80%EC%A0%95_ttest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from scipy.stats import ttest_1samp
from scipy.stats import ttest_ind
from scipy.stats import ttest_rel

# %%
df = pd.read_csv('iris.csv')
df.head(2)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
ttest_1samp(df['Sepal.Length'], popmean=4)
# Out:
# TtestResult(statistic=27.263680640799215, pvalue=8.764592435410748e-60, df=149)

# %%
result = ttest_1samp(df['Sepal.Length'], popmean=4)
result
# Out:
# TtestResult(statistic=27.263680640799215, pvalue=8.764592435410748e-60, df=149)

# %%
result[0]
# Out:
# 27.263680640799215

# %%
round(result[0], 3)
# Out:
# 27.264

# %%
stat, p = ttest_1samp(df['Sepal.Length'], popmean=4)
print(round(stat, 2))
print(round(p, 2))
# Out:
# 27.26
# 0.0

# %%
df['Sepal.Length'].mean()
# Out:
# 5.843333333333334

# %%
stat, p = ttest_1samp(df['Sepal.Length'], popmean=5.843)
print(round(stat, 2))
print(round(p, 2))
# Out:
# 0.0
# 1.0

# %%
stat, p = ttest_rel(df['Sepal.Length'], df['Sepal.Width'])
print(round(stat, 3))
print(round(p, 3))
# Out:
# 34.815
# 0.0

# %%
stat, p = ttest_ind(df.loc[df['Species'] == 'setosa', 'Petal.Length'],
                    df.loc[df['Species'] == 'versicolor', 'Petal.Length'])
print(round(stat, 3))
print(round(p, 3))
# Out:
# -39.493
# 0.0

# %% [markdown]
# ### 문제 1: 자료가 수집된 지역의 평균온도는 20도라고 한다. 수집된 데이터를 사용하여 양측 검정을 실시했을 때 p-value는 얼마인가?

# %%
df = pd.read_csv('bike.csv')
df.head(2)
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40

# %%
stat, p = ttest_1samp(df['temp'], popmean=20)
print(round(stat, 3))
print(round(p, 3))
# Out:
# 3.091
# 0.002

# %% [markdown]
# ### 문제 2: 2011년 1월의 데이터를 대상으로 동 시간대의 casual과 registered의 평균 차이 검정 시 검정통계량은?

# %%
df = pd.read_csv('bike.csv')
df.head(2)
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40

# %%
df['datetime'] = pd.to_datetime(df['datetime'])
df['year'] = df['datetime'].dt.year
df['month'] = df['datetime'].dt.month
df.head(2)
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
#
#    humidity  windspeed  casual  registered  count  year  month
# 0        81        0.0       3          13     16  2011      1
# 1        80        0.0       8          32     40  2011      1

# %%
df_sub = df.loc[(df['year'] == 2011) & (df['month'] == 1), ]
len(df_sub)
# Out:
# 431

# %%
stat, p = ttest_rel(df_sub['casual'], df_sub['registered'])
print(round(abs(stat), 3))
print(round(p, 3))
# Out:
# 21.41
# 0.0

# %% [markdown]
# ### 문제 3: 주중과 주말의 registered 평균 검정 시 검정통계량은?

# %%
df = pd.read_csv('bike.csv')
df.head(2)
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40

# %%
df['datetime'] = pd.to_datetime(df['datetime'])
df['wday'] = df['datetime'].dt.weekday
df['wend'] = (df['wday'] >= 5) + 0
df.head(2)
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
#
#    humidity  windspeed  casual  registered  count  wday  wend
# 0        81        0.0       3          13     16     5     1
# 1        80        0.0       8          32     40     5     1

# %%
stat, p = ttest_ind(df.loc[df['wend'] == 1, 'registered'],
                    df.loc[df['wend'] == 0, 'registered'])
print(round(abs(stat), 3))
print(round(p, 3))
# Out:
# 12.073
# 0.0
