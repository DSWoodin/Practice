# %% [markdown]
# <a href="https://colab.research.google.com/github/DSWoodin/Pythonworkspace/blob/main/ProDS/%EC%83%81%EA%B4%80%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from scipy.stats import pearsonr
from scipy.stats import spearmanr
from scipy.stats import kendalltau

# %%
df = pd.read_csv('bike.csv')
df.head(2)
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40

# %%
df = df.drop('datetime', axis=1)
df.head(2)
# Out:
#    season  holiday  workingday  weather  temp   atemp  humidity  windspeed  \
# 0       1        0           0        1  9.84  14.395        81        0.0
# 1       1        0           0        1  9.02  13.635        80        0.0
#
#    casual  registered  count
# 0       3          13     16
# 1       8          32     40

# %%
df.corr()
# Out:
#               season   holiday  workingday   weather      temp     atemp  \
# season      1.000000  0.029368   -0.008126  0.008879  0.258689  0.264744
# holiday     0.029368  1.000000   -0.250491 -0.007074  0.000295 -0.005215
# workingday -0.008126 -0.250491    1.000000  0.033772  0.029966  0.024660
# weather     0.008879 -0.007074    0.033772  1.000000 -0.055035 -0.055376
# temp        0.258689  0.000295    0.029966 -0.055035  1.000000  0.984948
# atemp       0.264744 -0.005215    0.024660 -0.055376  0.984948  1.000000
# humidity    0.190610  0.001929   -0.010880  0.406244 -0.064949 -0.043536
# windspeed  -0.147121  0.008409    0.013373  0.007261 -0.017852 -0.057473
# casual      0.096758  0.043799   -0.319111 -0.135918  0.467097  0.462067
# registered  0.164011 -0.020956    0.119460 -0.109340  0.318571  0.314635
# count       0.163439 -0.005393    0.011594 -0.128655  0.394454  0.389784
#
#             humidity  windspeed    casual  registered     count
# ...

# %%
df[['casual', 'registered', 'count']].corr()
# Out:
#               casual  registered     count
# casual      1.000000    0.497250  0.690414
# registered  0.497250    1.000000  0.970948
# count       0.690414    0.970948  1.000000

# %%
df[['casual', 'registered', 'count']].corr(method = 'spearman')
# Out:
#               casual  registered     count
# casual      1.000000    0.775785  0.847378
# registered  0.775785    1.000000  0.988901
# count       0.847378    0.988901  1.000000

# %%
pearsonr(df['casual'], df['registered'])
# Out:
# PearsonRResult(statistic=0.49724968508700806, pvalue=0.0)

# %%
stat, p = pearsonr(df['casual'], df['registered'])
print(stat)
print(p)
# Out:
# 0.49724968508700806
# 0.0

# %% [markdown]
# ### 문제 1: 기온, 체감온도, 상대습도, 총 자전거 대여 숫자의 상관관계를 분석하였을 때 가장 낮은 상관계수는 얼마인가?

# %%
df = pd.read_csv('bike.csv')
df.head(2)
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40

# %%
df[['temp', 'atemp', 'humidity', 'casual']].corr().round(2)
# Out:
#           temp  atemp  humidity  casual
# temp      1.00   0.98     -0.06    0.47
# atemp     0.98   1.00     -0.04    0.46
# humidity -0.06  -0.04      1.00   -0.35
# casual    0.47   0.46     -0.35    1.00

# %% [markdown]
# ### 문제 2: 계절별로 체감온도와 자전거 대여 숫자의 상관관계를 알아보고자 한다. 이 때 적절한 상관분석기법을 사용하였을 때 상관계수로 옳은 것은?

# %%
df = pd.read_csv('bike.csv')
df[['season', 'atemp', 'casual']].groupby('season').corr()
# Out:
#                   atemp    casual
# season
# 1      atemp   1.000000  0.478312
#        casual  0.478312  1.000000
# 2      atemp   1.000000  0.378122
#        casual  0.378122  1.000000
# 3      atemp   1.000000  0.381423
#        casual  0.381423  1.000000
# 4      atemp   1.000000  0.443751
#        casual  0.443751  1.000000

# %%
df_corr = df[['season', 'atemp', 'casual']].groupby('season').corr()
df_corr
# Out:
#                   atemp    casual
# season
# 1      atemp   1.000000  0.478312
#        casual  0.478312  1.000000
# 2      atemp   1.000000  0.378122
#        casual  0.378122  1.000000
# 3      atemp   1.000000  0.381423
#        casual  0.381423  1.000000
# 4      atemp   1.000000  0.443751
#        casual  0.443751  1.000000

# %%
df_corr = df_corr.reset_index()
df_corr
# Out:
#    season level_1     atemp    casual
# 0       1   atemp  1.000000  0.478312
# 1       1  casual  0.478312  1.000000
# 2       2   atemp  1.000000  0.378122
# 3       2  casual  0.378122  1.000000
# 4       3   atemp  1.000000  0.381423
# 5       3  casual  0.381423  1.000000
# 6       4   atemp  1.000000  0.443751
# 7       4  casual  0.443751  1.000000

# %%
df_corr = df_corr.loc[df_corr['atemp'] < 1]
df_corr
# Out:
#    season level_1     atemp  casual
# 1       1  casual  0.478312     1.0
# 3       2  casual  0.378122     1.0
# 5       3  casual  0.381423     1.0
# 7       4  casual  0.443751     1.0

# %% [markdown]
# ### 문제 3: 날씨에 따른 기온과 자전거 대여의 상관계수 변화를 알아보고자 한다. 날씨가 맑은 날과 그렇지 않은 날의 상관계수 차이의 절대값은 얼마인가?

# %%
df = pd.read_csv('bike.csv')
df.head(2)
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40

# %%
df['is_sunny'] = (df['weather'] == 1) + 0
df.head(2)
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
#
#    humidity  windspeed  casual  registered  count  is_sunny
# 0        81        0.0       3          13     16         1
# 1        80        0.0       8          32     40         1

# %%
df_corr = df.groupby('is_sunny')[['temp', 'casual']].corr()
df_corr
# Out:
#                      temp    casual
# is_sunny
# 0        temp    1.000000  0.446361
#          casual  0.446361  1.000000
# 1        temp    1.000000  0.471053
#          casual  0.471053  1.000000

# %%
round(abs(df_corr.iloc[1,0] - df_corr.iloc[3,0]), 3)
# Out:
# 0.025
