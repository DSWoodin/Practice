# %% [markdown]
# <a href="https://colab.research.google.com/github/DSWoodin/Pythonworkspace/blob/main/ProDS/%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%A0%84%EC%B2%98%EB%A6%AC_%EA%B2%B0%EC%B8%A1%EC%B9%98%EC%9D%B4%EC%83%81%EC%B9%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('iris_missing.csv')
df.head(7)
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1          NaN           NaN          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2     NaN
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2     NaN
# 5           5.4          3.9           1.7          0.4  setosa
# 6           NaN          NaN           NaN          NaN  setosa

# %%
df_na = df.head(7)
df_na
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1          NaN           NaN          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2     NaN
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2     NaN
# 5           5.4          3.9           1.7          0.4  setosa
# 6           NaN          NaN           NaN          NaN  setosa

# %%
df_na['Sepal_Length'].notna()
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6    False
# Name: Sepal_Length, dtype: bool

# %%
df_na['Sepal_Length'].isna()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# Name: Sepal_Length, dtype: bool

# %%
df_na['Sepal_Length'].isna().sum()
# Out:
# 1

# %%
df_na.isna()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width  Species
# 0         False         True          True        False    False
# 1         False        False         False        False    False
# 2         False        False         False        False     True
# 3         False        False         False        False    False
# 4         False        False         False        False     True
# 5         False        False         False        False    False
# 6          True         True          True         True    False

# %%
df_na.isna().sum() # 각 변수별 결측치 개수
# Out:
# Sepal_Length    1
# Sepal_Width     2
# Petal_Length    2
# Petal_Width     1
# Species         2
# dtype: int64

# %%
df_na.isna().sum(axis=1) # 각 row별 결측치 개수
# Out:
# 0    2
# 1    0
# 2    1
# 3    0
# 4    1
# 5    0
# 6    4
# dtype: int64

# %%
df_na
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1          NaN           NaN          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2     NaN
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2     NaN
# 5           5.4          3.9           1.7          0.4  setosa
# 6           NaN          NaN           NaN          NaN  setosa

# %%
df_na.fillna(value = {'Sepal_Length':999})
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1          NaN           NaN          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2     NaN
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2     NaN
# 5           5.4          3.9           1.7          0.4  setosa
# 6         999.0          NaN           NaN          NaN  setosa

# %%
df_na.fillna(value = {'Sepal_Length':999,
                      'Sepal_Width':999})
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1        999.0           NaN          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2     NaN
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2     NaN
# 5           5.4          3.9           1.7          0.4  setosa
# 6         999.0        999.0           NaN          NaN  setosa

# %%
df_na.fillna(value = 999)
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1        999.0         999.0          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2     999
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2     999
# 5           5.4          3.9           1.7          0.4  setosa
# 6         999.0        999.0         999.0        999.0  setosa

# %%
df_na["Sepal_Width"]
# Out:
# 0    NaN
# 1    3.0
# 2    3.2
# 3    3.1
# 4    3.6
# 5    3.9
# 6    NaN
# Name: Sepal_Width, dtype: float64

# %%
df_na["Sepal_Width"].mean() # 결측치를 제외하고 평균을 내줌
# Out:
# 3.3600000000000003

# %%
df_na.fillna(value = {"Sepal_Width":df_na["Sepal_Width"].mean()})
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1         3.36           NaN          0.2  setosa
# 1           4.9         3.00           1.4          0.2  setosa
# 2           4.7         3.20           1.3          0.2     NaN
# 3           4.6         3.10           1.5          0.2  setosa
# 4           5.0         3.60           1.4          0.2     NaN
# 5           5.4         3.90           1.7          0.4  setosa
# 6           NaN         3.36           NaN          NaN  setosa

# %%
df_na
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1          NaN           NaN          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2     NaN
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2     NaN
# 5           5.4          3.9           1.7          0.4  setosa
# 6           NaN          NaN           NaN          NaN  setosa

# %%
df_na = df_na.fillna(value = {"Sepal_Width":df_na["Sepal_Width"].mean()})
df_na
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1         3.36           NaN          0.2  setosa
# 1           4.9         3.00           1.4          0.2  setosa
# 2           4.7         3.20           1.3          0.2     NaN
# 3           4.6         3.10           1.5          0.2  setosa
# 4           5.0         3.60           1.4          0.2     NaN
# 5           5.4         3.90           1.7          0.4  setosa
# 6           NaN         3.36           NaN          NaN  setosa

# %%
df_na2 = df.head(7)
df_na2
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1          NaN           NaN          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2     NaN
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2     NaN
# 5           5.4          3.9           1.7          0.4  setosa
# 6           NaN          NaN           NaN          NaN  setosa

# %%
df_na2.dropna()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 1           4.9          3.0           1.4          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa

# %%
df_na2.dropna(how='all')
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1          NaN           NaN          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2     NaN
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2     NaN
# 5           5.4          3.9           1.7          0.4  setosa
# 6           NaN          NaN           NaN          NaN  setosa

# %%
df_na2.iloc[:,:-1].dropna(how='all') # 마지막 변수를 제외한 나머지를 뽑아서 dropna
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# 0           5.1          NaN           NaN          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2
# 5           5.4          3.9           1.7          0.4

# %%
print(df['Sepal_Length'].max())
print(df['Sepal_Length'].min())
print(df['Sepal_Length'].mean())
# Out:
# 7.9
# 4.3
# 5.8538461538461535

# %%
df['Sepal_Length'].median()
# Out:
# 5.8

# %%
df['Sepal_Length'].quantile()
# Out:
# 5.8

# %%
print(df['Sepal_Length'].quantile(q=0.25)) # 제 1 사분위수
print(df['Sepal_Length'].quantile(q=0.50)) # 제 2 사분위수
print(df['Sepal_Length'].quantile(q=0.75)) # 제 3 사분위수
# Out:
# 5.1
# 5.8
# 6.4

# %%
df = pd.read_csv ('iris_missing.csv')
df.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1          NaN           NaN          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2     NaN
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2     NaN

# %%
df.iloc[:,:-1].isna().sum()
# Out:
# Sepal_Length     7
# Sepal_Width     13
# Petal_Length    14
# Petal_Width      6
# dtype: int64

# %%
df.iloc[:,:-1].isna().sum().sum()
# Out:
# 40

# %%
df = df.fillna(value = {"Sepal_Width": df["Sepal_Width"].mean()})
df["Sepal_Width"].var()
# Out:
# 0.17561945818840935

# %%
df = pd.read_csv('iris.csv')
df.head(2)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
sl_mean = df["Sepal.Length"].mean()
sl_std = df["Sepal.Length"].std()
print(sl_mean)
print(sl_std)
# Out:
# 5.843333333333334
# 0.828066127977863

# %%
cond_1 = df["Sepal.Length"] < (sl_mean - 1.5 * sl_std)
cond_2 = df["Sepal.Length"] > (sl_mean + 1.5 * sl_std)
df_out = df.loc[cond_1 | cond_2, :]
len(df_out)
# Out:
# 21
