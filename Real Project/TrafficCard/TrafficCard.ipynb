# %% [markdown]
# ## 전국 지역별 교통카드 이용률 시각화

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' 
matplotlib.rcParams['font.size'] = 15 
matplotlib.rcParams['axes.unicode_minus'] = False

df = pd.read_csv('한국교통안전공단_전국 지역별 대중교통 이용 및 환승실태_20221231.csv', encoding='euc-kr')
df
# Out:
#                 구분1      서울      부산      대구      인천      광주      대전      울산  \
# 0    1주간대중교통이용횟수(회)    9.97    9.83   10.14    9.75     9.7    9.59    9.56
# 1     한달평균대중교통비용(원)  49,822  49,295  49,474  49,843  50,019  50,949  50,316
# 2     주이용교통수단_버스(%)    33.9    57.2    58.2    52.5      84    78.2     100
# 3   주이용교통수단_도시철도(%)    66.1    42.8    41.8    47.5      16    21.8       0
# 4        교통카드이용률(%)     100    99.6    99.6    99.7    99.1    99.6    99.7
# 5     정보제공서비스이용률(%)    95.9      95    95.9    95.1    95.1    95.8    95.8
# 6         접근소요시간(분)    8.31    7.98    8.01    8.03    7.89     7.9    7.81
# 7       환승서비스이용률(%)     100     100     100     100    99.9     100     100
# 8           환승횟수(회)     1.5    1.51     1.5     1.5    1.47    1.49    1.53
# 9         환승이동시간(분)    6.04    6.17    6.23    6.18    6.19    6.15     6.2
# 10        환승대기시간(분)    7.21    6.78     6.5     6.8    6.34    6.31    6.25
#
# ...

# %%
list(df.columns[1:])
# Out:
# ['서울',
#  '부산',
#  '대구',
#  '인천',
#  '광주',
#  '대전',
#  '울산',
#  '세종',
#  '경기',
#  '강원',
#  '충북',
#  '충남',
#  '전북',
#  '전남',
#  '경북',
#  '경남',
#  '제주']

# %%
list(df.iloc[4].values[1:])
# Out:
# ['100',
#  '99.6',
#  '99.6',
#  '99.7',
#  '99.1',
#  '99.6',
#  '99.7',
#  '99.7',
#  '99.3',
#  '93.1',
#  '94.8',
#  '94.8',
#  '96',
#  '90.4',
#  '92.5',
#  '95',
#  '99.1']

# %%
labels = list(df.columns[1:])
values = [float(num) for num in list(df.iloc[4].values[1:])]

plt.figure(figsize=(15,5))
plt.bar(labels, values, width=0.7, color='cornflowerblue', edgecolor='black', linewidth=0.5)
plt.ylabel('(%)', rotation=0, loc='bottom')
plt.ylim(89, 100)
plt.yticks([90, 95, 100])
plt.grid(True, axis='y', color='black', alpha=0.5, linestyle='--')
plt.title('전국 지역별 교통카드이용률(%)', pad=15)
for i in range(len(labels)):
    plt.text(labels[i], values[i], str(values[i]), ha='center', va='top')
plt.savefig('TrafficCard.png', dpi=100)
plt.show()
