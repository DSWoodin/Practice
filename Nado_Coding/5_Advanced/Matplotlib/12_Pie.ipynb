# %% [markdown]
# # 12. 원 그래프

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' 
matplotlib.rcParams['font.size'] = 15 
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
values = [1, 1, 1, 1, 1, 1]
labels = ['Python', 'Java', 'Javascript', 'C#', 'C/C++', 'ETC']

plt.pie(values, labels=labels, autopct='%.1f') # %.1f -> 소수점 첫째 자리까지
# autopct -> autopercent
plt.show()

# %%
values = [30, 25, 20, 13, 10, 2]
labels = ['Python', 'Java', 'Javascript', 'C#', 'C/C++', 'ETC']

plt.pie(values, labels=labels, autopct='%.1f%%', startangle=90, counterclock=False) 
# %% -> 소수점 첫째 + % 붙이기
# startangle -> 첫 데이터가 시작하는 지점 설정
# counterclock -> True가 default: 반시계방향으로 원 그래프 그려짐
plt.show()

# %%
values = [30, 25, 20, 13, 10, 2]
labels = ['Python', 'Java', 'Javascript', 'C#', 'C/C++', 'ETC']
explode = [0.2, 0.1, 0, 0, 0, 0] # 파이썬은 0.2만큼, 자바는 0.1만큼, 나머지는 0만큼 띄움

plt.pie(values, labels=labels, explode=explode)
plt.show()

# %%
values = [30, 25, 20, 13, 10, 2]
labels = ['Python', 'Java', 'Javascript', 'C#', 'C/C++', 'ETC']
explode = [0.05] * 6

plt.pie(values, labels=labels, explode=explode)
plt.show()

# %%
plt.pie(values, labels=labels, explode=explode)
plt.legend()
plt.show()

# %%
plt.pie(values, labels=labels, explode=explode)
plt.legend(loc=(1.2, 0.3), title='언어별 선호도')
plt.show()

# %%
plt.pie(values, labels=labels, explode=explode)
plt.title('언어별 선호도')
plt.legend(loc=(1.2, 0.3), title='언어')
plt.show()

# %%
values = [30, 25, 20, 13, 10, 2]
labels = ['Python', 'Java', 'Javascript', 'C#', 'C/C++', 'ETC']
colors = ['#ffadad', '#ffd6a5', '#fdffb6', '#caffbf', '#9bf6ff', '#a0c4ff']
explode = [0.05] * 6
wedgeprops = {'width':0.6} # 도넛 형태로 만들기

plt.pie(values, labels=labels, autopct='%.1f%%', startangle=90, 
        counterclock=False, colors=colors, explode=explode, wedgeprops=wedgeprops) 
plt.show()

# ETC와 Python explode 간격이 안예쁨

# %%
values = [30, 25, 20, 13, 10, 2]
labels = ['Python', 'Java', 'Javascript', 'C#', 'C/C++', 'ETC']
colors = ['#ffadad', '#ffd6a5', '#fdffb6', '#caffbf', '#9bf6ff', '#a0c4ff']
wedgeprops = {'width':0.6, 'edgecolor':'w', 'linewidth':3}
# edgecolor를 white 색상으로 설정해줌으로써 explode와 비슷한 효과 하지만 더 예쁜 결과

plt.pie(values, labels=labels, autopct='%.1f%%', startangle=90, 
        counterclock=False, colors=colors, wedgeprops=wedgeprops) 
plt.show()

# %%
def custom_autopct(pct):
    return('%.1f%%' % pct) if pct >= 10 else '' 
# 10% 이상만 표기, 미만은 미표기(정확히는 ''(빈칸) 표기)

plt.pie(values, labels=labels, autopct=custom_autopct, startangle=90, 
        counterclock=False, colors=colors, wedgeprops=wedgeprops) 
plt.show()

# %%
def custom_autopct(pct):
    return'{:.1f}%'.format(pct) if pct >= 10 else ''
  # return('%.1f%%' % pct) if pct >= 10 else '' 와 똑같음
# '{:.1f}%'.format(pct) -> 기본편 practice18.py 참고


plt.pie(values, labels=labels, autopct=custom_autopct, startangle=90, 
        counterclock=False, colors=colors, wedgeprops=wedgeprops) 
plt.show()

# %%
def custom_autopct(pct):
    return'{:.0f}%'.format(pct) if pct >= 10 else ''


plt.pie(values, labels=labels, autopct=custom_autopct, startangle=90, 
        counterclock=False, colors=colors, wedgeprops=wedgeprops, pctdistance=0.7)
        # pctdistance -> 퍼센트 표기의 위치를 변경
plt.show()

# %% [markdown]
# ### DataFrame 활용

# %%
import pandas as pd
df = pd.read_excel('../Pandas/score.xlsx')
df
# Out:
#   지원번호   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0   1번  채치수  북산고  197   90   85  100  95  85      Python
# 1   2번  정대만  북산고  184   40   35   50  55  25        Java
# 2   3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3   4번  서태웅  북산고  187   40   60   70  75  80         NaN
# 4   5번  강백호  북산고  188   15   20   10  35  10         NaN
# 5   6번  변덕규  능남고  202   80  100   95  85  80           C
# 6   7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7   8번  윤대협  능남고  190  100   85   90  95  95          C#

# %%
grp = df.groupby('학교')
grp.size()
# Out:
# 학교
# 능남고    3
# 북산고    5
# dtype: int64

# %%
grp.size()['능남고']
# Out:
# 3

# %%
values = [grp.size()['북산고'], grp.size()['능남고']] # [5, 3]
labels = ['북산고', '능남고']

plt.pie(values, labels=labels)
plt.title('소속 학교')
plt.show()
